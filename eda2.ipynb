# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\dugge\\Documents\\NareshiT\\eda'

# %%
import pandas as pd
city=['hyd','vij','mtm']
names=['sa','kiran','kumar']
age=[20,30,45]
ind=['a','b','c']
df=pd.DataFrame(zip(names,age,city),index=ind,columns=['names','age','city'])

# %%
df
# Out:
#    names  age city
# a     sa   20  hyd
# b  kiran   30  vij
# c  kumar   45  mtm

# %%
df.to_csv('data3.csv')

# %%
import pandas as pd
pd.read_csv('data3.csv')
# Out:
#   Unnamed: 0  names  age city
# 0          a     sa   20  hyd
# 1          b  kiran   30  vij
# 2          c  kumar   45  mtm

# %%
os.getcwd()
# Out:
# 'C:\\Users\\dugge\\Documents\\NareshiT\\eda'

# %%
pd.read_csv('data3.csv')
# Out:
#   Unnamed: 0  names  age city
# 0          a     sa   20  hyd
# 1          b  kiran   30  vij
# 2          c  kumar   45  mtm

# %%
import pandas as pd
pd.read_csv(r'C:\Users\dugge\Documents\NareshiT\eda\bank_csv.csv')
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
dict1={'names':['sai','kiran','kumar'],'ages':[25,24,34]}
pd.DataFrame(dict1)
# Out:
#    names  ages
# 0    sai    25
# 1  kiran    24
# 2  kumar    34
