# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv('visa.csv')
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
l1=['prevailing_wage','yr_of_estab','no_of_employees']
prev=[]
est=[]
emp=[]
for i in l1:
    wage_count=round(len(visa_df[i]),2)
    wage_min=round(visa_df[i].min(),2)
    wage_max=round(visa_df[i].max(),2)
    wage_mean=round(visa_df[i].mean(),2)
    wage_median=round(visa_df[i].median(),2)
    wage_std=round(visa_df[i].std(),2)
    list_values=[wage_count,wage_min,wage_max,
    wage_mean,wage_median,wage_std]
    index_val=['count','min','max','mean','median','std']
    l2=[wage_count,wage_min,wage_max,wage_mean,wage_median,wage_std]
    for j in l2:
        
      if i=='prevailing_wage':
        prev.append(j)
      elif i=='yr_of_estab':
        est.append(j)
      elif i=='no_of_employees':
        emp.append(j)
pd.DataFrame(zip(prev,est,emp),columns=l1,index=index_val)
# Out:
#         prevailing_wage  yr_of_estab  no_of_employees
# count          25480.00     25480.00         25480.00
# min                2.14      1800.00           -26.00
# max           319210.27      2016.00        602069.00
# mean           74455.81      1979.41          5667.04
# median         70308.21      1997.00          2109.00
# std            52815.94        42.37         22877.93

# %% [markdown]
# **DEASCRIBE**

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# **HISTOGRSM**

# %%
plt.hist(visa_df['prevailing_wage'])
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)

# %%
v1=visa_df['prevailing_wage']>=2.1367
v2=visa_df['prevailing_wage']<31922.95
len(visa_df[v1&v2])
# Out:
# 6038

# %%
n=plt.hist(visa_df['prevailing_wage'],bins=20)

# %%
plt.title('HISTOGRAM')
plt.xlabel('CI')
plt.ylabel('count')
n=plt.hist(visa_df['prevailing_wage'],bins=20)

# %%
l1=['prevailing_wage','yr_of_estab','no_of_employees']
plt.subplot(1,3,j)
plt.title('HISTOGRAM')
plt.xlabel('CI')
plt.ylabel('count')
n=plt.hist(visa_df['prevailing_wage'],bins=20)

plt.subplot(1,3,2)
plt.title('HISTOGRAM')
plt.xlabel('CI')
plt.ylabel('count')
n=plt.hist(visa_df['yr_of_estab'],bins=20)


plt.subplot(1,3,3)
plt.title('HISTOGRAM')
plt.xlabel('CI')
plt.ylabel('count')
n=plt.hist(visa_df['no_of_employees'],bins=20)

# %%
l1=['prevailing_wage','yr_of_estab','no_of_employees']
j=1
for i in l1:
   plt.subplot(1,3,j)
   plt.title('HISTOGRAM')
   plt.xlabel('CI')
   plt.ylabel('count')
   n=plt.hist(visa_df[i],bins=20)
   j=j+1

# %%
import seaborn as sns
sns.histplot(visa_df['prevailing_wage'])
# Out:
# C:\Users\dugge\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='prevailing_wage', ylabel='Count'>

# %%
sns.distplot(visa_df['prevailing_wage'])
# Out:
# C:\Users\dugge\AppData\Local\Temp\ipykernel_6748\1386266348.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(visa_df['prevailing_wage'])
# C:\Users\dugge\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='prevailing_wage', ylabel='Density'>

# %%
import warnings
warnings.filterwarnings("ignore")
sns.distplot(visa_df['prevailing_wage'])
# Out:
# <Axes: xlabel='prevailing_wage', ylabel='Density'>
